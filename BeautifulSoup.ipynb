# %%
from twitter import Twitter, OAuth

# %%
import os

# %%
from pprint import pprint

# %%
#key: Apj4bkaOQEYZ2ruCYmxpeKEBI
#secretkey: lpXVL7iTbkern1NKBhg4BXhzUKGuCJIiswtQlgVNDtsHNSEap2
#bearertoken: AAAAAAAAAAAAAAAAAAAAAD3NGwEAAAAAmI18oQLi90c3SdGGHyEZgbC8USo%3DqM4UN0oT3iIDwx9gn8GsmjbCpgAfnb7xiUM7nVX6nrGm0g7fnx

# %%
consumer_key = "Apj4bkaOQEYZ2ruCYmxpeKEBI"
consumer_secret = "IpXVL7iTbkern1NKBhg4BXhzUKGuCJIiswtQlgVNDtsHNSEap2" 
access_token = "872859870311190528-RlmxEVElFM9mlqkf9dVcs0W6O78m3nv"
access_token_secret = "54jsvKMhcVEUkaPozSrZb3kfaDUp8K2pp7auZ0Z2F4yel"

t = Twitter(auth=OAuth(access_token, access_token_secret, consumer_key, consumer_secret))

# %%
python_tweets = t.search.tweets(q="#Mulan", count=100)
len(python_tweets['statuses']) # how many tweets

for tw_obj in python_tweets['statuses']:
    print(tw_obj['text'])
    
# pprint(len(python_tweets['statuses']))
# negative_words = ['boring', 'awful', 'bad']
# positive_words = ['amazing', 'excited', 'great']
# Out:
# https://t.co/k8RNWKcVFf
# #Mulan
# #ZaraBukanJKT48
# #Musik
# RT @micha__0126: #Disneyprincess
# #Jasmine #Mulan https://t.co/0n9jLI2TAn
# RT @DisneyStudios: Loyal. Brave. True. Art by @CryssyCheung. Start streaming Disney's #Mulan September 4 exclusively on #DisneyPlus with Pr…
# RT @MajorGroup: เผยภาพชุดใหม่จากหนังดิสนีย์ไลฟ์แอคชั่นฟอร์มยักษ์แห่งปี Disney's #Mulan #มู่หลาน
#
# ซื้อตั๋วล่วงหน้าได้แล้ววันนี้
# เข้าฉายศุก…
# @GESSwrites @sherrythomas Gracias @GESSwrites. So nice to meet you @sherrythomas. I just signed up for the Sept. 1s… https://t.co/uldxFi2vgv
# RT @kileyqallen: I urge you all to boycott the new #Mulan coming to #DisneyPlus soon. Mulan has forever been my FAVORITE Disney tale; yet t…
# RT @MajorGroup: เผยภาพชุดใหม่จากหนังดิสนีย์ไลฟ์แอคชั่นฟอร์มยักษ์แห่งปี Disney's #Mulan #มู่หลาน
#
# ซื้อตั๋วล่วงหน้าได้แล้ววันนี้
# เข้าฉายศุก…
# @StephMillerShow iPhones, the Bic Lighters of today.
# But in these times, why not?
# ...
